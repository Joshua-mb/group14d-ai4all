# %%
import pandas as pd

sentiment_df = pd.read_csv('stock_tweets_with_sentiment.csv')
sentiment_df.head()
# Out:
#          Date                                              Tweet Stock Name  \
# 0  2022-09-29  Mainstream media has done an amazing job at br...       TSLA
# 1  2022-09-29  Tesla delivery estimates are at around 364k fr...       TSLA
# 2  2022-09-29  3/ Even if I include 63.0M unvested RSUs as of...       TSLA
# 3  2022-09-29  @RealDanODowd @WholeMarsBlog @Tesla Hahaha why...       TSLA
# 4  2022-09-29  @RealDanODowd @Tesla Stop trying to kill kids,...       TSLA
#
#   Company Name  sentiment_negative  sentiment_neutral  sentiment_positive  \
# 0  Tesla, Inc.               0.125              0.763               0.113
# 1  Tesla, Inc.               0.000              1.000               0.000
# 2  Tesla, Inc.               0.000              0.954               0.046
# 3  Tesla, Inc.               0.273              0.590               0.137
# 4  Tesla, Inc.               0.526              0.474               0.000
#
#    sentiment_compound sentiment_label
# 0              0.0772        Positive
# 1              0.0000         Neutral
# 2              0.2960        Positive
# 3             -0.7568        Negative
# 4             -0.8750        Negative

# %%
# Select only specific tech stocks from the dataset
tech_sentiment_df = sentiment_df.loc[sentiment_df['Stock Name'].isin(['AAPL', 'GOOG', 'INTC', 'META', 'MSFT'])]
tech_sentiment_df
# Out:
#              Date                                              Tweet  \
# 37422  2022-09-29  A group of lawmakers led by Sen. Elizabeth War...
# 37423  2022-09-29  $NIO just because I'm down money doesn't mean ...
# 37424  2022-09-29  Today’s drop in $SPX is a perfect example of w...
# 37425  2022-09-29  Druckenmiller owned $CVNA this year \nMunger b...
# 37426  2022-09-29  Top 10 $QQQ Holdings \n\nAnd Credit Rating\n\n...
# ...           ...                                                ...
# 75810  2021-10-17  A packed earnings week!\n\n$STT\n$ELS\n$ACO\n$...
# 75811  2021-10-16  💥BIG WEEK OF Q3 EARNINGS AHEAD 👀👀\n\nMon: -\nT...
# 75812  2021-10-16  A packed earnings week!\n\n$STT\n$ELS\n$ACO\n$...
# 75813  2021-10-14  TSMC node transitions are slowing down heavily...
# 75814  2021-10-07  Confirmed #earnings for October \n\nhttps://t....
#
#       Stock Name           Company Name  sentiment_negative  \
# 37422       MSFT  Microsoft Corporation               0.079
# 37423       MSFT  Microsoft Corporation               0.155
# 37424       MSFT  Microsoft Corporation               0.161
# 37425       MSFT  Microsoft Corporation               0.064
# 37426       MSFT  Microsoft Corporation               0.000
# ...          ...                    ...                 ...
# 75810       INTC      Intel Corporation               0.000
# 75811       INTC      Intel Corporation               0.000
# 75812       INTC      Intel Corporation               0.000
# 75813       INTC      Intel Corporation               0.113
# 75814       INTC      Intel Corporation               0.000
#
#        sentiment_neutral  sentiment_positive  sentiment_compound  \
# 37422              0.850               0.070             -0.0772
# 37423              0.690               0.155              0.2500
# 37424              0.777               0.061             -0.6197
# 37425              0.854               0.082              0.2382
# 37426              0.830               0.170              0.7783
# ...                  ...                 ...                 ...
# 75810              0.956               0.044              0.3164
# 75811              1.000               0.000              0.0000
# 75812              0.956               0.044              0.3164
# 75813              0.887               0.000             -0.6792
# 75814              0.949               0.051              0.3680
#
#       sentiment_label
# 37422        Negative
# 37423        Positive
# 37424        Negative
# 37425        Positive
# 37426        Positive
# ...               ...
# 75810        Positive
# 75811         Neutral
# 75812        Positive
# 75813        Negative
# 75814        Positive
#
# [13502 rows x 9 columns]

# %%
# Create separate dataframes for each stock with selected columns
selected_columns = ['Date', 'Stock Name', 'sentiment_negative', 'sentiment_neutral', 'sentiment_positive', 'sentiment_compound']

# Dictionary to store dataframes for each stock
stock_dfs = {}

# Create separate dataframes for each stock
for stock in ['AAPL', 'GOOG', 'INTC', 'META', 'MSFT']:
    stock_dfs[stock] = tech_sentiment_df[tech_sentiment_df['Stock Name'] == stock][selected_columns].copy()
    print(f"\nFirst few rows of {stock} dataframe:")
    print(stock_dfs[stock].head())
# Out:
# First few rows of AAPL dataframe:
#              Date Stock Name  sentiment_negative  sentiment_neutral  \
# 55958  2022-09-29       AAPL               0.155              0.690
# 55959  2022-09-29       AAPL               0.000              0.918
# 55960  2022-09-29       AAPL               0.000              1.000
# 55961  2022-09-29       AAPL               0.092              0.708
# 55962  2022-09-29       AAPL               0.143              0.857
#
#        sentiment_positive  sentiment_compound
# 55958               0.155              0.2500
# 55959               0.082              0.3612
# 55960               0.000              0.0000
# 55961               0.200              0.6126
# 55962               0.000             -0.6523
#
# First few rows of GOOG dataframe:
#              Date Stock Name  sentiment_negative  sentiment_neutral  \
# 52440  2022-09-29       GOOG               0.000              0.830
# 52441  2022-09-29       GOOG               0.000              0.842
# 52442  2022-09-29       GOOG               0.065              0.935
# 52443  2022-09-29       GOOG               0.104              0.896
# 52444  2022-09-29       GOOG               0.044              0.956
#
#        sentiment_positive  sentiment_compound
# 52440               0.170              0.7783
# 52441               0.158              0.7184
# 52442               0.000             -0.3612
# 52443               0.000             -0.4215
# 52444               0.000             -0.2732
#
# First few rows of INTC dataframe:
#              Date Stock Name  sentiment_negative  sentiment_neutral  \
# 75500  2022-09-29       INTC               0.204              0.796
# 75501  2022-09-28       INTC               0.000              1.000
# 75502  2022-09-27       INTC               0.000              0.714
# 75503  2022-09-26       INTC               0.041              0.877
# 75504  2022-09-26       INTC               0.000              1.000
#
#        sentiment_positive  sentiment_compound
# 75500               0.000             -0.8271
# 75501               0.000              0.0000
# 75502               0.286              0.7783
# 75503               0.082              0.2960
# 75504               0.000              0.0000
#
# First few rows of META dataframe:
#              Date Stock Name  sentiment_negative  sentiment_neutral  \
# 45600  2022-09-29       META               0.163              0.689
# 45601  2022-09-25       META               0.114              0.886
# 45602  2022-09-22       META               0.000              0.929
# 45603  2022-09-22       META               0.000              0.894
# 45604  2022-09-22       META               0.217              0.783
#
#        sentiment_positive  sentiment_compound
# 45600               0.148             -0.0516
# 45601               0.000             -0.7096
# 45602               0.071              0.5859
# 45603               0.106              0.4939
# 45604               0.000             -0.5160
#
# First few rows of MSFT dataframe:
#              Date Stock Name  sentiment_negative  sentiment_neutral  \
# 37422  2022-09-29       MSFT               0.079              0.850
# 37423  2022-09-29       MSFT               0.155              0.690
# 37424  2022-09-29       MSFT               0.161              0.777
# 37425  2022-09-29       MSFT               0.064              0.854
# 37426  2022-09-29       MSFT               0.000              0.830
#
#        sentiment_positive  sentiment_compound
# 37422               0.070             -0.0772
# 37423               0.155              0.2500
# 37424               0.061             -0.6197
# 37425               0.082              0.2382
# 37426               0.170              0.7783

# %%
# Calculate daily average sentiments for each stock
daily_stock_dfs = {}

for stock in stock_dfs:
    # Group by date and calculate mean of sentiment columns
    daily_stock_dfs[stock] = stock_dfs[stock].groupby('Date').agg({
        'sentiment_negative': 'mean',
        'sentiment_neutral': 'mean',
        'sentiment_positive': 'mean',
        'sentiment_compound': 'mean'
    }).reset_index()
    
    # Add stock name column back
    daily_stock_dfs[stock]['Stock Name'] = stock
    
    print(f"\nFirst few rows of {stock} daily averaged dataframe:")
    print(daily_stock_dfs[stock].head())
# Out:
# First few rows of AAPL daily averaged dataframe:
#          Date  sentiment_negative  sentiment_neutral  sentiment_positive  \
# 0  2021-09-30            0.051286           0.851143            0.097571
# 1  2021-10-01            0.024455           0.872455            0.103182
# 2  2021-10-02            0.021500           0.935500            0.043000
# 3  2021-10-03            0.000000           0.839000            0.161000
# 4  2021-10-04            0.030900           0.910000            0.059300
#
#    sentiment_compound Stock Name
# 0            0.098900       AAPL
# 1            0.248255       AAPL
# 2            0.007525       AAPL
# 3            0.822500       AAPL
# 4            0.122830       AAPL
#
# First few rows of GOOG daily averaged dataframe:
#          Date  sentiment_negative  sentiment_neutral  sentiment_positive  \
# 0  2021-09-30             0.00000             0.4080               0.592
# 1  2021-10-01             0.17350             0.8265               0.000
# 2  2021-10-02             0.01600             0.8890               0.095
# 3  2021-10-03             0.00000             0.9480               0.052
# 4  2021-10-04             0.11775             0.7785               0.104
#
#    sentiment_compound Stock Name
# 0            0.440400       GOOG
# 1           -0.494350       GOOG
# 2            0.327767       GOOG
# 3            0.381800       GOOG
# 4            0.197075       GOOG
#
# First few rows of INTC daily averaged dataframe:
#          Date  sentiment_negative  sentiment_neutral  sentiment_positive  \
# 0  2021-10-07               0.000           0.949000            0.051000
# 1  2021-10-14               0.113           0.887000            0.000000
# 2  2021-10-16               0.000           0.978000            0.022000
# 3  2021-10-17               0.000           0.985333            0.014667
# 4  2021-10-18               0.636           0.364000            0.000000
#
#    sentiment_compound Stock Name
# 0            0.368000       INTC
# 1           -0.679200       INTC
# 2            0.158200       INTC
# 3            0.105467       INTC
# 4           -0.542300       INTC
#
# First few rows of META daily averaged dataframe:
#          Date  sentiment_negative  sentiment_neutral  sentiment_positive  \
# 0  2021-09-30            0.015667           0.848667            0.135667
# 1  2021-10-01            0.023455           0.914000            0.062455
# 2  2021-10-02            0.029000           0.786000            0.185000
# 3  2021-10-03            0.075000           0.783000            0.141000
# 4  2021-10-04            0.071391           0.854328            0.074313
#
#    sentiment_compound Stock Name
# 0            0.472467       META
# 1            0.230900       META
# 2            0.860000       META
# 3            0.276900       META
# 4            0.046167       META
#
# First few rows of MSFT daily averaged dataframe:
#          Date  sentiment_negative  sentiment_neutral  sentiment_positive  \
# 0  2021-09-30            0.032000           0.830200            0.138000
# 1  2021-10-01            0.020875           0.865375            0.113750
# 2  2021-10-02            0.056333           0.848333            0.095333
# 3  2021-10-03            0.000000           0.839000            0.161000
# 4  2021-10-04            0.015167           0.868917            0.115917
#
#    sentiment_compound Stock Name
# 0            0.256980       MSFT
# 1            0.359650       MSFT
# 2           -0.000700       MSFT
# 3            0.822500       MSFT
# 4            0.279425       MSFT

# %%
# Add sentiment label based on compound score
for stock in daily_stock_dfs:
    # Create sentiment label using numpy where
    daily_stock_dfs[stock]['sentiment_label'] = 'Neutral'  # default value
    
    # Update based on conditions
    daily_stock_dfs[stock].loc[daily_stock_dfs[stock]['sentiment_compound'] >= 0.05, 'sentiment_label'] = 'Positive'
    daily_stock_dfs[stock].loc[daily_stock_dfs[stock]['sentiment_compound'] <= -0.05, 'sentiment_label'] = 'Negative'
    
    print(f"\nFirst few rows of {stock} dataframe with sentiment labels:")
    print(daily_stock_dfs[stock].head())
# Out:
# First few rows of AAPL dataframe with sentiment labels:
#          Date  sentiment_negative  sentiment_neutral  sentiment_positive  \
# 0  2021-09-30            0.051286           0.851143            0.097571
# 1  2021-10-01            0.024455           0.872455            0.103182
# 2  2021-10-02            0.021500           0.935500            0.043000
# 3  2021-10-03            0.000000           0.839000            0.161000
# 4  2021-10-04            0.030900           0.910000            0.059300
#
#    sentiment_compound Stock Name sentiment_label
# 0            0.098900       AAPL        Positive
# 1            0.248255       AAPL        Positive
# 2            0.007525       AAPL         Neutral
# 3            0.822500       AAPL        Positive
# 4            0.122830       AAPL        Positive
#
# First few rows of GOOG dataframe with sentiment labels:
#          Date  sentiment_negative  sentiment_neutral  sentiment_positive  \
# 0  2021-09-30             0.00000             0.4080               0.592
# 1  2021-10-01             0.17350             0.8265               0.000
# 2  2021-10-02             0.01600             0.8890               0.095
# 3  2021-10-03             0.00000             0.9480               0.052
# 4  2021-10-04             0.11775             0.7785               0.104
#
#    sentiment_compound Stock Name sentiment_label
# 0            0.440400       GOOG        Positive
# 1           -0.494350       GOOG        Negative
# 2            0.327767       GOOG        Positive
# 3            0.381800       GOOG        Positive
# 4            0.197075       GOOG        Positive
#
# First few rows of INTC dataframe with sentiment labels:
#          Date  sentiment_negative  sentiment_neutral  sentiment_positive  \
# 0  2021-10-07               0.000           0.949000            0.051000
# 1  2021-10-14               0.113           0.887000            0.000000
# 2  2021-10-16               0.000           0.978000            0.022000
# 3  2021-10-17               0.000           0.985333            0.014667
# 4  2021-10-18               0.636           0.364000            0.000000
#
#    sentiment_compound Stock Name sentiment_label
# 0            0.368000       INTC        Positive
# 1           -0.679200       INTC        Negative
# 2            0.158200       INTC        Positive
# 3            0.105467       INTC        Positive
# 4           -0.542300       INTC        Negative
#
# First few rows of META dataframe with sentiment labels:
#          Date  sentiment_negative  sentiment_neutral  sentiment_positive  \
# 0  2021-09-30            0.015667           0.848667            0.135667
# 1  2021-10-01            0.023455           0.914000            0.062455
# 2  2021-10-02            0.029000           0.786000            0.185000
# 3  2021-10-03            0.075000           0.783000            0.141000
# 4  2021-10-04            0.071391           0.854328            0.074313
#
#    sentiment_compound Stock Name sentiment_label
# 0            0.472467       META        Positive
# 1            0.230900       META        Positive
# 2            0.860000       META        Positive
# 3            0.276900       META        Positive
# 4            0.046167       META         Neutral
#
# First few rows of MSFT dataframe with sentiment labels:
#          Date  sentiment_negative  sentiment_neutral  sentiment_positive  \
# 0  2021-09-30            0.032000           0.830200            0.138000
# 1  2021-10-01            0.020875           0.865375            0.113750
# 2  2021-10-02            0.056333           0.848333            0.095333
# 3  2021-10-03            0.000000           0.839000            0.161000
# 4  2021-10-04            0.015167           0.868917            0.115917
#
#    sentiment_compound Stock Name sentiment_label
# 0            0.256980       MSFT        Positive
# 1            0.359650       MSFT        Positive
# 2           -0.000700       MSFT         Neutral
# 3            0.822500       MSFT        Positive
# 4            0.279425       MSFT        Positive

# %%
# Save each stock's dataframe to a CSV file
for stock in daily_stock_dfs:
    filename = f"{stock}_avg_sentiment_data.csv"
    daily_stock_dfs[stock].to_csv(filename, index=False)
    print(f"Saved {filename}")
# Out:
# Saved AAPL_avg_sentiment_data.csv
# Saved GOOG_avg_sentiment_data.csv
# Saved INTC_avg_sentiment_data.csv
# Saved META_avg_sentiment_data.csv
# Saved MSFT_avg_sentiment_data.csv
